# %% [markdown]
# # Cryptocurrency Recommendation System Visualizations
# ### Authors
#
#
# |    Student Name                 |    Student Number  |
# |---------------------------------|--------------------|
# | Raj Sandhu                      | 101111960          |
# | Akaash Kapoor                   | 101112895          |
# | Ali Alvi                        | 101114940          |
# | Hassan Jallad                   | 101109334          |
# | Areeb Ul Haq                    | 101115337          |
# | Ahmad Abuoudeh                  | 101072636          |

# %% [markdown]
# ## Libraries To Install

# %%
! pip install kneed
# installs kneed library which is used to determine the knee point to be used for recommendation systems.
# Out:
# Requirement already satisfied: kneed in c:\users\raj20\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: scipy in c:\users\raj20\anaconda3\lib\site-packages (from kneed) (1.7.1)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\raj20\anaconda3\lib\site-packages (from kneed) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\raj20\anaconda3\lib\site-packages (from kneed) (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raj20\anaconda3\lib\site-packages (from matplotlib->kneed) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\raj20\anaconda3\lib\site-packages (from matplotlib->kneed) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raj20\anaconda3\lib\site-packages (from matplotlib->kneed) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\raj20\anaconda3\lib\site-packages (from matplotlib->kneed) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\raj20\anaconda3\lib\site-packages (from matplotlib->kneed) (0.10.0)
# Requirement already satisfied: six in c:\users\raj20\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->kneed) (1.16.0)

# %% [markdown]
# ## Libraries To Import

# %%
import json
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from kneed import KneeLocator

# %% [markdown]
# ## Read In Coin Similarity Matrices and Processed Coin Dataset

# %%
parent_folder = os.path.dirname(os.path.dirname(os.getcwd())) #Parent folder of the repo
model_folder = "models" #Name of folder that the similarity matrices are stored.
data_folder = "data" #Name of folder that the coin data it stored.
proc_folder = "processed" #Name of folder that the processed coin dataset is stored.
reports_folder = "reports" #Name of parent folder where generated plots will be stored.
figures_folder = "figures" #Name of folder where generated plots will be stored.
src_folder = "src" #Name of source folder.
model_data_file_path = os.path.join(parent_folder, model_folder) #path to models folder
processed_data_file_path = os.path.join(parent_folder, data_folder, proc_folder) #Path to processed coin dataset.
figures_data_file_path = os.path.join(parent_folder, reports_folder, figures_folder) #Path to processed coin dataset.
src_models_file_path = os.path.join(parent_folder, src_folder, model_folder) #Path to .json file with target coin name.

#load in data from cvs files
coin_df_wmd = pd.read_csv(open(os.path.join(model_data_file_path, "coin-similarity-matrix-description.csv"), "r"), index_col="Name")
coin_df_ed = pd.read_csv(open(os.path.join(model_data_file_path, "coin-similarity-matrix-euclidean-distance.csv"), "r"), index_col="Name")
coin_df_weighted_avg = pd.read_csv(open(os.path.join(model_data_file_path, "coin-similarity-matrix-weighted-average.csv"), "r"), index_col="Name")
processed_coin_df = pd.read_csv(open(os.path.join(processed_data_file_path, "coin-info.csv"), "r"))

#test output of the wmd similarity matrix.
coin_df_wmd
# Out:
#                        iota  anchor-protocol  compound  bitcoin-sv      drep  \
# Name
# iota               0.000000         3.170357  2.171160    2.229937  2.735465
# anchor-protocol    3.170357         0.000000  3.326736    3.277865  3.407600
# compound           2.171160         3.326736  0.000000    2.281674  2.891091
# bitcoin-sv         2.229937         3.277865  2.281674    0.000000  2.843226
# drep               2.735465         3.407600  2.891091    2.843226  0.000000
# ...                     ...              ...       ...         ...       ...
# nexus-mutual       2.190762         3.253310  2.407950    2.465231  2.844083
# juno               2.375256         3.346427  2.410279    2.507217  2.840785
# okb                2.178784         3.152493  2.302774    2.308496  2.764615
# avalanche          2.516597         3.380975  2.489660    2.574286  2.836954
# compound-usd-coin  2.509003         3.372036  2.248290    2.623275  3.020076
#
#                    moonbeam  usd-coin  chainlink  basic-attention-token  \
# Name
# iota               2.258385  2.208431   2.103930               2.225857
# anchor-protocol    3.268028  3.369509   3.340737               3.381832
# compound           2.400574  2.188473   2.137912               2.133458
# bitcoin-sv         2.393085  2.277789   2.277939               2.292242
# drep               2.810384  2.868590   2.770253               2.926254
# ...                     ...       ...        ...                    ...
# nexus-mutual       2.458540  2.456764   2.374419               2.428557
# juno               2.363450  2.412082   2.239042               2.504455
# okb                2.014560  2.286681   2.299715               2.352729
# avalanche          2.317926  2.612435   2.414112               2.605800
# compound-usd-coin  2.642462  2.435877   2.611225               2.592755
#
#                    bittorrent  ...      gala  bitcoin-gold  render-token  \
# Name                           ...
# iota                 2.376386  ...  2.772715      2.334604      2.705839
# anchor-protocol      3.322350  ...  3.450060      3.292741      3.360755
# compound             2.439778  ...  2.925447      2.358951      2.770554
# bitcoin-sv           2.510614  ...  2.917513      2.098307      2.752338
# drep                 2.970365  ...  2.998832      2.827450      3.008179
# ...                       ...  ...       ...           ...           ...
# nexus-mutual         2.453446  ...  2.867152      2.513954      2.761209
# juno                 2.621340  ...  3.086009      2.510507      2.909125
# okb                  2.253653  ...  2.818819      2.235299      2.675767
# avalanche            2.601057  ...  3.019100      2.538815      2.715792
# compound-usd-coin    2.673152  ...  3.040454      2.472249      2.911146
#
#                    unfoldu-group-coin-(new)     maker  nexus-mutual      juno  \
# Name
# iota                               2.391945  2.102176      2.190762  2.375256
# anchor-protocol                    3.208156  3.191857      3.253310  3.346427
# compound                           2.393285  1.800100      2.407950  2.410279
# bitcoin-sv                         2.477368  2.233188      2.465231  2.507217
# drep                               2.844016  2.881863      2.844083  2.840785
# ...                                     ...       ...           ...       ...
# nexus-mutual                       2.371646  2.399128      0.000000  2.518541
# juno                               2.545965  2.367397      2.518541  0.000000
# okb                                2.259754  2.232096      2.237765  2.388843
# avalanche                          2.550356  2.554725      2.583840  2.540172
# compound-usd-coin                  2.486353  2.439741      2.703363  2.738081
#
#                         okb  avalanche  compound-usd-coin
# Name
# iota               2.178784   2.516597           2.509003
# anchor-protocol    3.152493   3.380975           3.372036
# compound           2.302774   2.489660           2.248290
# bitcoin-sv         2.308496   2.574286           2.623275
# drep               2.764615   2.836954           3.020076
# ...                     ...        ...                ...
# nexus-mutual       2.237765   2.583840           2.703363
# juno               2.388843   2.540172           2.738081
# okb                0.000000   2.387466           2.515510
# avalanche          2.387466   0.000000           2.863573
# compound-usd-coin  2.515510   2.863573           0.000000
#
# [141 rows x 141 columns]

# %%
#Test output of the Euclidean Distance similarity matrix
coin_df_ed
# Out:
#                        iota  anchor-protocol  compound  bitcoin-sv      drep  \
# Name
# iota               0.000000         0.000468  0.094384    0.039394  0.000059
# anchor-protocol    0.000468         0.000000  0.093916    0.038926  0.000409
# compound           0.094384         0.093916  0.000000    0.054990  0.094325
# bitcoin-sv         0.039394         0.038926  0.054990    0.000000  0.039335
# drep               0.000059         0.000409  0.094325    0.039335  0.000000
# ...                     ...              ...       ...         ...       ...
# nexus-mutual       0.017720         0.017252  0.076663    0.021673  0.017661
# juno               0.005296         0.004828  0.089088    0.034098  0.005237
# okb                0.003586         0.003118  0.090798    0.035808  0.003527
# avalanche          0.020100         0.019632  0.074284    0.019294  0.020041
# compound-usd-coin  0.000237         0.000705  0.094621    0.039630  0.000296
#
#                    moonbeam      usd-coin  chainlink  basic-attention-token  \
# Name
# iota               0.001550  2.368410e-04   0.004297               0.000071
# anchor-protocol    0.001082  7.048557e-04   0.003829               0.000539
# compound           0.092834  9.462082e-02   0.090087               0.094455
# bitcoin-sv         0.037844  3.963052e-02   0.035097               0.039465
# drep               0.001491  2.958295e-04   0.004238               0.000130
# ...                     ...           ...        ...                    ...
# nexus-mutual       0.016170  1.795732e-02   0.013423               0.017791
# juno               0.003746  5.532731e-03   0.000999               0.005367
# okb                0.002036  3.822801e-03   0.000711               0.003657
# avalanche          0.018550  2.033654e-02   0.015803               0.020171
# compound-usd-coin  0.001787  7.998537e-08   0.004534               0.000166
#
#                      bittorrent  ...      gala  bitcoin-gold  render-token  \
# Name                             ...
# iota               2.371535e-04  ...  0.000132      0.014342      0.000775
# anchor-protocol    7.051683e-04  ...  0.000600      0.013874      0.000307
# compound           9.462113e-02  ...  0.094516      0.080042      0.093609
# bitcoin-sv         3.963083e-02  ...  0.039526      0.025052      0.038619
# drep               2.961421e-04  ...  0.000191      0.014283      0.000716
# ...                         ...  ...       ...           ...           ...
# nexus-mutual       1.795763e-02  ...  0.017853      0.003379      0.016946
# juno               5.533044e-03  ...  0.005428      0.009046      0.004521
# okb                3.823114e-03  ...  0.003718      0.010756      0.002811
# avalanche          2.033685e-02  ...  0.020232      0.005758      0.019325
# compound-usd-coin  3.925014e-07  ...  0.000104      0.014578      0.001012
#
#                    unfoldu-group-coin-(new)     maker  nexus-mutual      juno  \
# Name
# iota                           2.362516e-04  0.477463      0.017720  0.005296
# anchor-protocol                7.042663e-04  0.476995      0.017252  0.004828
# compound                       9.462023e-02  0.383079      0.076663  0.089088
# bitcoin-sv                     3.962993e-02  0.438069      0.021673  0.034098
# drep                           2.952401e-04  0.477404      0.017661  0.005237
# ...                                     ...       ...           ...       ...
# nexus-mutual                   1.795673e-02  0.459743      0.000000  0.012425
# juno                           5.532142e-03  0.472167      0.012425  0.000000
# okb                            3.822212e-03  0.473877      0.014135  0.001710
# avalanche                      2.033595e-02  0.457363      0.002379  0.014804
# compound-usd-coin              5.094735e-07  0.477700      0.017957  0.005533
#
#                         okb  avalanche  compound-usd-coin
# Name
# iota               0.003586   0.020100           0.000237
# anchor-protocol    0.003118   0.019632           0.000705
# compound           0.090798   0.074284           0.094621
# bitcoin-sv         0.035808   0.019294           0.039630
# drep               0.003527   0.020041           0.000296
# ...                     ...        ...                ...
# nexus-mutual       0.014135   0.002379           0.017957
# juno               0.001710   0.014804           0.005533
# okb                0.000000   0.016514           0.003823
# avalanche          0.016514   0.000000           0.020336
# compound-usd-coin  0.003823   0.020336           0.000000
#
# [141 rows x 141 columns]

# %%
#Test output of the weighted average similarity matrix
coin_df_weighted_avg
# Out:
#                        iota  anchor-protocol  compound  bitcoin-sv      drep  \
# Name
# iota               0.000000         1.585413  1.132772    1.134665  1.367762
# anchor-protocol    1.585413         0.000000  1.710326    1.658395  1.704004
# compound           1.132772         1.710326  0.000000    1.168332  1.492708
# bitcoin-sv         1.134665         1.658395  1.168332    0.000000  1.441280
# drep               1.367762         1.704004  1.492708    1.441280  0.000000
# ...                     ...              ...       ...         ...       ...
# nexus-mutual       1.104241         1.635281  1.242307    1.243452  1.430872
# juno               1.190276         1.675627  1.249684    1.270657  1.423011
# okb                1.091185         1.577806  1.196786    1.172152  1.384071
# avalanche          1.268348         1.700303  1.281972    1.296790  1.428498
# compound-usd-coin  1.254620         1.686370  1.171455    1.331453  1.510186
#
#                    moonbeam  usd-coin  chainlink  basic-attention-token  \
# Name
# iota               1.129967  1.104334   1.054114               1.112964
# anchor-protocol    1.634555  1.685107   1.672283               1.691185
# compound           1.246704  1.141547   1.113999               1.113956
# bitcoin-sv         1.215464  1.158710   1.156518               1.165853
# drep               1.405938  1.434443   1.387245               1.463192
# ...                     ...       ...        ...                    ...
# nexus-mutual       1.237355  1.237361   1.193921               1.223174
# juno               1.183598  1.208807   1.120020               1.254911
# okb                1.008298  1.145252   1.150213               1.178193
# avalanche          1.168238  1.316386   1.214957               1.312986
# compound-usd-coin  1.322125  1.217939   1.307879               1.296460
#
#                    bittorrent  ...      gala  bitcoin-gold  render-token  \
# Name                           ...
# iota                 1.188312  ...  1.386424      1.174473      1.353307
# anchor-protocol      1.661528  ...  1.725330      1.653308      1.680531
# compound             1.267199  ...  1.509982      1.219497      1.432081
# bitcoin-sv           1.275123  ...  1.478520      1.061680      1.395479
# drep                 1.485330  ...  1.499512      1.420867      1.504448
# ...                       ...  ...       ...           ...           ...
# nexus-mutual         1.235702  ...  1.442503      1.258667      1.389077
# juno                 1.313437  ...  1.545719      1.259777      1.456823
# okb                  1.128738  ...  1.411269      1.123027      1.339289
# avalanche            1.310697  ...  1.519666      1.272287      1.367558
# compound-usd-coin    1.336576  ...  1.520279      1.243414      1.456079
#
#                    unfoldu-group-coin-(new)     maker  nexus-mutual      juno  \
# Name
# iota                               1.196091  1.289819      1.104241  1.190276
# anchor-protocol                    1.604430  1.834426      1.635281  1.675627
# compound                           1.243953  1.091590      1.242307  1.249684
# bitcoin-sv                         1.258499  1.335629      1.243452  1.270657
# drep                               1.422156  1.679634      1.430872  1.423011
# ...                                     ...       ...           ...       ...
# nexus-mutual                       1.194801  1.429435      0.000000  1.265483
# juno                               1.275749  1.419782      1.265483  0.000000
# okb                                1.131788  1.352987      1.125950  1.195276
# avalanche                          1.285346  1.506044      1.293109  1.277488
# compound-usd-coin                  1.243177  1.458720      1.360660  1.371807
#
#                         okb  avalanche  compound-usd-coin
# Name
# iota               1.091185   1.268348           1.254620
# anchor-protocol    1.577806   1.700303           1.686370
# compound           1.196786   1.281972           1.171455
# bitcoin-sv         1.172152   1.296790           1.331453
# drep               1.384071   1.428498           1.510186
# ...                     ...        ...                ...
# nexus-mutual       1.125950   1.293109           1.360660
# juno               1.195276   1.277488           1.371807
# okb                0.000000   1.201990           1.259666
# avalanche          1.201990   0.000000           1.441955
# compound-usd-coin  1.259666   1.441955           0.000000
#
# [141 rows x 141 columns]

# %%
#Test output of the processed coin info dataset.
processed_coin_df
# Out:
#                   Name  Volatility  \
# 0                 iota    0.388529
# 1      anchor-protocol    1.155277
# 2             compound  155.017778
# 3           bitcoin-sv   64.927187
# 4                 drep    0.485170
# ..                 ...         ...
# 136       nexus-mutual   29.419982
# 137               juno    9.064785
# 138                okb    6.263407
# 139          avalanche   33.317865
# 140  compound-usd-coin    0.000643
#
#                                            Description
# 0    IOTA (IOTA or MIOTA) is a cryptocurrency token...
# 1    Anchor Protocol is a yield stable and attracti...
# 2    COMP is an ERC-20 token built on the Ethereum ...
# 3    Bitcoin SV is a cryptocurrency that was create...
# 4    DREPis committed to building a performance-ori...
# ..                                                 ...
# 136  Nexus Mutal is a new concept that is built as ...
# 137  Jun is an open source platform for interoperab...
# 138  OKB is a utility token issued by the OKB found...
# 139  Avalanche is an open-source platform for launc...
# 140  Compound USD Coin (cUSD) is acToken used by th...
#
# [141 rows x 3 columns]

# %% [markdown]
# The target coin for which we wish to determine similar coins to is stored in the coin_data.json file. The reason for this is to ensure the security and maintainability of the developed codebase. For example, if this project were handed off to a client, it would be preferable for them to modify the desired coin name within the JSON file instead of changing a hardcoded coin name within this script, potentially changing something in the code unintentionally which could cause it to break.

# %% [markdown]
# ## Read In Target Coin Name

# %%
with open(os.path.join(src_models_file_path, "coin_data.json")) as f :
    name = json.load(f) #Read the JSON file which stores the coin name.

target_coin_name = name["coinName"] #Extract the coin name from the JSON file.
print(target_coin_name)
# Out:
# usd-coin

# %% [markdown]
# The target coin for which we wish to determine similar coins to is stored in the coin_data.json file. The reason for this is to ensure the security and maintainability of the developed codebase. For example, if this project were handed off to a client, it would be preferable for them to modify the desired coin name within the JSON file instead of changing a hardcoded coin name within this script, potentially changing something in the code unintentionally which could cause it to break.

# %% [markdown]
# ## Determine Sorted Similarities to Target Coin

# %%
#Function to sort coins in ascending order in terms of their similarity to a target coin.
def output_similarity(df, coin_name) :
    scores = list(enumerate(df[coin_name]))
    sorted_scores = sorted(scores, key = lambda x :x[1], reverse = False)
    sorted_scores = sorted_scores[1:] #Removes first measure in sorted coin list. This is needed to remove self similarity. For example we do not care if a coin is exactly the same as itself.
    return sorted_scores

#Function that returns the number of coins in the sorted list. It is used when determing the number of similar coins to recommend through the kneed method.
def num_coins(score_list) :
    num_coins = []
    for i in range(1, len(score_list) + 1) :
        num_coins.append(i)
    return num_coins

#Function that returns sorted list of coins in terms of their similarity to a target coin.
def coin_data(df, coin_name) :
    coins = list(df[coin_name])
    sorted_coins = sorted(coins)
    sorted_coins = sorted_coins[1:]
    return sorted_coins

#Function that outputs the n-number of similar coins to the target coin.
def num_similar_coins(df, score_list, kneedle_point, coin_name, method) :
    j = 0
    print("The top " + str(kneedle_point) + " coins to " + coin_name + " by method of " + method + " are: ")
    for item in score_list :
        similar_coin_name = processed_coin_df["Name"][item[0]]
        print(similar_coin_name) #Printing similar coin names.
        j +=1
        if j > int(kneedle_point) - 1 : #Stop after n coins have been printed.
            break

# %% [markdown]
# ## Visualizations For Analytical Methods

# %%
wmd_coin_similarity = output_similarity(coin_df_wmd, target_coin_name) #Get sorted similarity of coins in comparison to the target coin.
wmd_num_coins = num_coins(wmd_coin_similarity) #Get the number of sorted coins.
wmd_coin_data = coin_data(coin_df_wmd, target_coin_name) #Gets sorted coin list which is used to determine knee point.
kneedle_wmd = KneeLocator(wmd_num_coins, wmd_coin_data) #Locate the knee point of the data. This will act as the threshold of the number of similar coins to output.
kneedle_wmd.plot_knee() #Plot Knee point on graph.
plt.title("Knee Point of " + target_coin_name + " From Word Mover's Distance Method") #Give plot Descriptive title.
plt.xlabel("Coin Threshold to Consider") #Set the x axis label of the plot.
plt.ylabel("Sorted Similarities to Target Coin") #Set the y axis label of the plot.
plt.savefig(os.path.join(figures_data_file_path, "wmd-knee-point-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.

# %%
ed_coin_similarity = output_similarity(coin_df_ed, target_coin_name) #Get sorted similarity of coins in comparison to the target coin.
ed_num_coins = num_coins(ed_coin_similarity)  #Get the number of sorted coins.
ed_coin_data = coin_data(coin_df_ed, target_coin_name) #Gets sorted coin list which is used to determine knee point.
kneedle_ed = KneeLocator(ed_num_coins, ed_coin_data) #Locate the knee point of the data. This will act as the threshold of the number of similar coins to output.
kneedle_ed.plot_knee() #Plot Knee point on graph.
plt.title("Knee Point of " + target_coin_name + " From Euclidean Distance Method") #Give plot Descriptive title.
plt.xlabel("Coin Threshold to Consider") #Set the x axis label of the plot.
plt.ylabel("Sorted Similarities to Target Coin") #Set the y axis label of the plot.
plt.savefig(os.path.join(figures_data_file_path, "ed-knee-point-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.

# %%
weighted_average_coin_similarity = output_similarity(coin_df_weighted_avg, target_coin_name) #Get sorted similarity of coins in comparison to the target coin.
weighted_average_num_coins = num_coins(weighted_average_coin_similarity) #Get the number of sorted coins.
weighted_average_coin_data = coin_data(coin_df_weighted_avg, target_coin_name) #Gets sorted coin list which is used to determine knee point.
kneedle_weighted_average = KneeLocator(weighted_average_num_coins, weighted_average_coin_data) #Locate the knee point of the data. This will act as the threshold of the number of similar coins to output.
kneedle_weighted_average.plot_knee() #Plot Knee point on graph.
plt.title("Knee Point of " + target_coin_name + " From Weighted Average Method") #Give plot Descriptive title.
plt.xlabel("Coin Threshold to Consider") #Set the x axis label of the plot.
plt.ylabel("Sorted Similarities to Target Coin") #Set the y axis label of the plot.
plt.savefig(os.path.join(figures_data_file_path, "weighted-average-knee-point-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.

# %%
sns.displot(
    data = coin_df_ed[target_coin_name],
    kind = "kde"
) #Creates a KDE plot.
plt.title("Kernel Density Estimation Plot of " + target_coin_name + " Volatility Similarity") #Set Title of plot.
plt.savefig(os.path.join(figures_data_file_path, "kde-volatility-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.

# %%
plt.hist(coin_df_wmd[target_coin_name]) #Creates a histogram plot.
plt.title("Histogram of " + target_coin_name + " Description Similarity") #Set title of plot.
plt.xlabel("Coin Similarity")
plt.ylabel("Number of Similar Coins")
plt.savefig(os.path.join(figures_data_file_path, "histogram-description-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.

# %%
sns.displot(
    data = coin_df_weighted_avg[target_coin_name],
    kind = "kde"
) #Creates a KDE plot.
plt.title("Kernel Density Estimation Plot of " + target_coin_name + " Weighted Average of Metrics Similarity") #Set title of plot.
plt.savefig(os.path.join(figures_data_file_path, "kde-weighted-metric-average-plot-" + target_coin_name + ".jpg"), bbox_inches = "tight") #Save Plot to previously set directoy.
